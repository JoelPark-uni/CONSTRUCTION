# %%
import cv2, os
import numpy as np

# %%
path = "./data/Training/TS_OBJ/"
files = os.listdir(path)

files = [file for file in files if file.endswith(".PNG")]

# %%
for file in files :
    img = cv2.imread(os.path.join(path, file), cv2.IMREAD_COLOR)
    dst = cv2.resize(img, (1024, 1024))
    cv2.imwrite("./"+file, dst)
    break

img.shape
# Out:
# (3509, 4963, 3)

# %%
dst = cv2.resize(img, (512, 512))
dst.shape
# Out:
# (512, 512, 3)

# %%
from PIL import Image
import matplotlib.pyplot as plt

plt.imshow(dst)
plt.show()

# %%
import torch

torch_list =
